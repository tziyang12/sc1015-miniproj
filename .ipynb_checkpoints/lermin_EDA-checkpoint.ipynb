# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
data = pd.read_csv('non_zero_data.csv')
data.head()
# Out:
#    adult        genre_ids   id original_language  popularity release_date  \
# 0  False         [18, 80]  278                en     136.776   1994-09-23
# 1  False         [18, 80]  238                en     107.889   1972-03-14
# 2  False         [18, 80]  240                en      71.355   1974-12-20
# 3  False  [18, 36, 10752]  424                en      79.614   1993-12-15
# 4  False  [16, 10751, 14]  129                ja     120.883   2001-07-20
#
#                       title  vote_average  vote_count      revenue  \
# 0  The Shawshank Redemption         8.704       25822   28341469.0
# 1             The Godfather         8.695       19602  245066411.0
# 2     The Godfather Part II         8.576       11849  102600000.0
# 3          Schindler's List         8.566       15229  321365567.0
# 4             Spirited Away         8.541       15705  274925095.0
#
#                    production_companies      budget  release_year  \
# 0         ['Castle Rock Entertainment']  25000000.0          1994
# 1   ['Paramount', 'Alfran Productions']   6000000.0          1972
# 2  ['Paramount', 'The Coppola Company']  13000000.0          1974
# 3              ['Amblin Entertainment']  22000000.0          1993
# 4                     ['Studio Ghibli']  19000000.0          2001
#
#    release_month  num_genres release_season  budget_revenue_ratio
# 0              9           2           Fall              0.882100
# 1              3           2         Spring              0.024483
# 2             12           2         Winter              0.126706
# 3             12           3         Winter              0.068458
# 4              7           3         Summer              0.069110

# %%
data['profit_margin'] = (data['revenue'] - data['budget']) / data['revenue']

# Print the DataFrame with the new 'profit_margin' column
data.head()
# Out:
#    adult        genre_ids   id original_language  popularity release_date  \
# 0  False         [18, 80]  278                en     136.776   1994-09-23
# 1  False         [18, 80]  238                en     107.889   1972-03-14
# 2  False         [18, 80]  240                en      71.355   1974-12-20
# 3  False  [18, 36, 10752]  424                en      79.614   1993-12-15
# 4  False  [16, 10751, 14]  129                ja     120.883   2001-07-20
#
#                       title  vote_average  vote_count      revenue  \
# 0  The Shawshank Redemption         8.704       25822   28341469.0
# 1             The Godfather         8.695       19602  245066411.0
# 2     The Godfather Part II         8.576       11849  102600000.0
# 3          Schindler's List         8.566       15229  321365567.0
# 4             Spirited Away         8.541       15705  274925095.0
#
#                    production_companies      budget  release_year  \
# 0         ['Castle Rock Entertainment']  25000000.0          1994
# 1   ['Paramount', 'Alfran Productions']   6000000.0          1972
# 2  ['Paramount', 'The Coppola Company']  13000000.0          1974
# 3              ['Amblin Entertainment']  22000000.0          1993
# 4                     ['Studio Ghibli']  19000000.0          2001
#
#    release_month  num_genres release_season  budget_revenue_ratio  \
# 0              9           2           Fall              0.882100
# 1              3           2         Spring              0.024483
# 2             12           2         Winter              0.126706
# 3             12           3         Winter              0.068458
# 4              7           3         Summer              0.069110
#
#    profit_margin
# 0       0.117900
# 1       0.975517
# 2       0.873294
# 3       0.931542
# 4       0.930890

# %%
#compare the budget revenue ratio with profit margin to gain insights about financial state
#compare each movies financial state if they have properly budgeted 
financial_performance = pd.DataFrame(data[['budget_revenue_ratio','profit_margin']])

financial_performance.head()
# Out:
#    budget_revenue_ratio  profit_margin
# 0              0.882100       0.117900
# 1              0.024483       0.975517
# 2              0.126706       0.873294
# 3              0.068458       0.931542
# 4              0.069110       0.930890

# %%
try:
    f, axes = plt.subplots(6, 3, figsize=(18, 24))

    count = 0
    for var in financial_performance:
        sb.boxplot(data=financial_performance[var], orient="h", ax=axes[count, 0])
        sb.histplot(data=financial_performance[var], ax=axes[count, 1])
        sb.violinplot(data=financial_performance[var], orient="h", ax=axes[count, 2])
        count += 1

    plt.show()

except Exception as e:
    print("An error occurred:", e)

# %%
try:
    f, axes = plt.subplots(6, 3, figsize=(18, 24))

    count = 0
    for var in financial_performance:
        sb.boxplot(data=financial_performance[var], orient="h", ax=axes[count, 0])
        sb.histplot(data=financial_performance[var], ax=axes[count, 1])
        sb.violinplot(data=financial_performance[var], orient="h", ax=axes[count, 2])
        count += 1

    plt.show()

except Exception as e:
    print("An error occurred:", e)
